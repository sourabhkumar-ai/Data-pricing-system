# %%
display(dbutils.fs.ls("/Volumes/workspace/datalake/bronze_landing_zone"))

# %%
df_events  = spark.read\
    .option("header","true")\
        .option("inferschema","true")\
            .csv("/Volumes/workspace/datalake/bronze_landing_zone/events.csv")

# %%
df_events.show(10)

# %%
df_events.printSchema()
display(df_events)

# %%
from pyspark.sql.functions import *
df_events = df_events.withColumn("timestamp",from_unixtime(col("timestamp")/1000).cast("timestamp"))
df_events.show(10)
